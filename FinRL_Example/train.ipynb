# %% [markdown]
# ### Import Necessary Packages ###

# %%
import pandas as pd
import numpy as np

from stable_baselines3 import A2C, PPO, DDPG, TD3, SAC, DQN
from stable_baselines3.common.logger import configure

from finrl.meta.preprocessor.preprocessors import data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent 

from finrl import config
from finrl import config_tickers
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
TRAIN_START_DATE = '2014-06-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-02'
TEST_END_DATE = '2023-04-01'
TIME_INTERVAL = '1D'

# %% [markdown]
# Load stocks data from datasets

# %%
data = pd.read_csv("datasets/processed_data.csv")

# %%
data
# Out:
#              date       tic     open    close     high      low     volume
# 0      2014-06-03  sh600028     8.72     8.79     8.87     8.69   423628.0  \
# 1      2014-06-03  sh600029     3.87     3.86     3.89     3.86   161877.0
# 2      2014-06-03  sh600276   366.83   374.56   376.35   366.83    27404.0
# 3      2014-06-03  sh600309   408.06   407.64   412.45   407.43    46705.0
# 4      2014-06-03  sh600436    88.60    88.07    89.26    87.86     3512.0
# ...           ...       ...      ...      ...      ...      ...        ...
# 65125  2023-04-28  sz002230   726.93   794.57   798.45   722.28  1064697.0
# 65126  2023-04-28  sz002352   178.19   176.54   179.66   175.82   153159.0
# 65127  2023-04-28  sz002594   262.72   257.11   264.22   255.25   191945.0
# 65128  2023-04-28  sz002714   864.07   853.28   865.79   848.82   225879.0
# 65129  2023-04-28  sz300015  1398.59  1380.17  1404.11  1372.35   330609.0
#
#              amount       macd      boll_ub      boll_lb     rsi_30
# 0      2.132521e+08   0.000000     8.790000     8.790000   0.000000  \
# 1      3.766733e+07   0.000000     8.790000     8.790000   0.000000
# 2      9.013581e+07   0.000000     8.790000     8.790000   0.000000
# 3      7.839471e+07   0.000000     8.790000     8.790000   0.000000
# 4      2.705420e+07   0.000000     8.790000     8.790000   0.000000
# ...             ...        ...          ...          ...        ...
# 65125  6.231633e+09  10.437358   888.264578   709.311422  55.666886
# 65126  8.686714e+08   0.983021   182.392753   167.429247  52.808157
# 65127  4.933613e+09   0.315811   260.448325   241.664675  50.493915
# 65128  1.082817e+09  -5.187115   897.822024   834.556976  47.085182
# 65129  9.756602e+08 -19.544619  1494.143587  1322.092413  46.444817
#
#            cci_30       dx_30  close_30_sma  close_60_sma  turbulence
# 0      -66.666667  100.000000      8.790000      8.790000    0.000000
# 1      -66.666667  100.000000      3.860000      3.860000    0.000000
# 2      -66.666667  100.000000    374.560000    374.560000    0.000000
# 3      -66.666667  100.000000    407.640000    407.640000    0.000000
# 4      -66.666667  100.000000     88.070000     88.070000    0.000000
# ...           ...         ...           ...           ...         ...
# 65125  -14.914221   30.664523    777.236667    708.070333   89.449365
# 65126   80.806878   25.694144    172.571000    172.061500   89.449365
# 65127  142.661589   22.906747    249.163000    258.980333   89.449365
# 65128  -37.662762    2.986640    861.463000    869.143167   89.449365
# 65129  -79.437582    5.347962   1417.939667   1447.049500   89.449365
#
# [65130 rows x 17 columns]

# %%
train = data_split(data, TRAIN_START_DATE, TRAIN_END_DATE)
test = data_split(data, TEST_START_DATE, TEST_END_DATE)

# %%
train.shape
# Out:
# (48240, 17)

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 301

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

train_kwargs = {
    "hmax": 100,
    "initial_amount": 100000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

env_train = StockTradingEnv(df = train, **train_kwargs)

# %%
agent = DRLAgent(env = env_train)

PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

# set up logger
tmp_path = RESULTS_DIR + "/ppo"
new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Set new logger
model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# -----------------------------------
# | rollout/           |            |
# |    ep_len_mean     | 1.61e+03   |
# |    ep_rew_mean     | 132        |
# | time/              |            |
# |    fps             | 168        |
# |    iterations      | 1          |
# |    time_elapsed    | 12         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.08663344 |
# -----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 79.4         |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.015913932  |
# |    clip_fraction        | 0.208        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.6        |
# |    explained_variance   | -0.0278      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.87         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.025       |
# |    reward               | -0.022484647 |
# |    std                  | 1            |
# |    value_loss           | 13.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 50.8         |
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 3            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.022615364  |
# |    clip_fraction        | 0.293        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.7        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0779       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0226      |
# |    reward               | -0.009314891 |
# |    std                  | 1.01         |
# |    value_loss           | 1            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 36.7        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 4           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.024486307 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.441      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0238     |
# |    reward               | 0.004916335 |
# |    std                  | 1.01        |
# |    value_loss           | 0.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 38.3        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 5           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016881518 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.692       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0179     |
# |    reward               | 0.027543202 |
# |    std                  | 1.02        |
# |    value_loss           | 2.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 32.1        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 6           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.01626598  |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.74        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0152     |
# |    reward               | -0.14732598 |
# |    std                  | 1.02        |
# |    value_loss           | 3.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.61e+03   |
# |    ep_rew_mean          | 36.1       |
# | time/                   |            |
# |    fps                  | 173        |
# |    iterations           | 7          |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.0329447  |
# |    clip_fraction        | 0.287      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.1      |
# |    explained_variance   | 0.0665     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.207      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0163    |
# |    reward               | -0.9865832 |
# |    std                  | 1.02       |
# |    value_loss           | 3.78       |
# ----------------------------------------
# day: 1607, episode: 10
# begin_total_asset: 100000.00
# end_total_asset: 387571.21
# total_reward: 287571.21
# total_cost: 145251.81
# total_trades: 32632
# Sharpe: 0.681
# =================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 37.6        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 8           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.022265565 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.06        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | -0.14556499 |
# |    std                  | 1.02        |
# |    value_loss           | 4.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 36.9        |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 9           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018397797 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.079       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | -0.30830634 |
# |    std                  | 1.02        |
# |    value_loss           | 1.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 44.7        |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 10          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024482893 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.3       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.88        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0204     |
# |    reward               | 0.915444    |
# |    std                  | 1.03        |
# |    value_loss           | 8           |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.61e+03      |
# |    ep_rew_mean          | 45.3          |
# | time/                   |               |
# |    fps                  | 176           |
# |    iterations           | 11            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.02123246    |
# |    clip_fraction        | 0.245         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -43.4         |
# |    explained_variance   | 0.159         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.24          |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.0132       |
# |    reward               | -0.0065039345 |
# |    std                  | 1.03          |
# |    value_loss           | 10            |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 42.4        |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 12          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016930565 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.5       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.04        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.017      |
# |    reward               | 0.09240488  |
# |    std                  | 1.03        |
# |    value_loss           | 3.26        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 55.4         |
# | time/                   |              |
# |    fps                  | 175          |
# |    iterations           | 13           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.02080452   |
# |    clip_fraction        | 0.237        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -43.6        |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.00546      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0164      |
# |    reward               | -0.011843036 |
# |    std                  | 1.04         |
# |    value_loss           | 0.493        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 51.6        |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 14          |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015814448 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.4        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.012      |
# |    reward               | -1.4417547  |
# |    std                  | 1.04        |
# |    value_loss           | 36          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 175          |
# |    iterations           | 15           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.02140929   |
# |    clip_fraction        | 0.254        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -43.7        |
# |    explained_variance   | 0.37         |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.14         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0122      |
# |    reward               | -0.006855412 |
# |    std                  | 1.04         |
# |    value_loss           | 3.09         |
# ------------------------------------------
# day: 1607, episode: 20
# begin_total_asset: 100000.00
# end_total_asset: 3178356.10
# total_reward: 3078356.10
# total_cost: 680441.42
# total_trades: 38321
# Sharpe: 0.640
# =================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 63.2        |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 16          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.026485324 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.8       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0396      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.012      |
# |    reward               | -0.17354292 |
# |    std                  | 1.04        |
# |    value_loss           | 1.29        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 65.3        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 17          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017741151 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.8       |
# |    explained_variance   | 0.0973      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00854    |
# |    reward               | 0.002034428 |
# |    std                  | 1.04        |
# |    value_loss           | 69.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.61e+03   |
# |    ep_rew_mean          | 62.2       |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 18         |
# |    time_elapsed         | 210        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02496045 |
# |    clip_fraction        | 0.284      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.9      |
# |    explained_variance   | 0.291      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.44       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00926   |
# |    reward               | 0.8220995  |
# |    std                  | 1.05       |
# |    value_loss           | 6.05       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 60.1        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 19          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.030723155 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.9       |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.34        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0102     |
# |    reward               | 0.025999064 |
# |    std                  | 1.05        |
# |    value_loss           | 8.66        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 58.1         |
# | time/                   |              |
# |    fps                  | 174          |
# |    iterations           | 20           |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.020581141  |
# |    clip_fraction        | 0.238        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -44          |
# |    explained_variance   | 0.609        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0514      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0195      |
# |    reward               | -0.005860258 |
# |    std                  | 1.05         |
# |    value_loss           | 1.29         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 55.5        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 21          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.025000006 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.1       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.301      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0169     |
# |    reward               | -2.312801   |
# |    std                  | 1.06        |
# |    value_loss           | 0.52        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.61e+03     |
# |    ep_rew_mean          | 53.8         |
# | time/                   |              |
# |    fps                  | 174          |
# |    iterations           | 22           |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.01970874   |
# |    clip_fraction        | 0.258        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -44.2        |
# |    explained_variance   | 0.0624       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.923        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0125      |
# |    reward               | -0.020872172 |
# |    std                  | 1.06         |
# |    value_loss           | 5.71         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 54.3        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 23          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.022067837 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.4       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.367       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0118     |
# |    reward               | -0.19897413 |
# |    std                  | 1.06        |
# |    value_loss           | 3.02        |
# -----------------------------------------
# day: 1607, episode: 30
# begin_total_asset: 100000.00
# end_total_asset: 111704.73
# total_reward: 11704.73
# total_cost: 83716.61
# total_trades: 31947
# Sharpe: 0.399
# =================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.61e+03   |
# |    ep_rew_mean          | 52.6       |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 24         |
# |    time_elapsed         | 281        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02680239 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -44.5      |
# |    explained_variance   | 0.25       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.8        |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0136    |
# |    reward               | 7.263407   |
# |    std                  | 1.07       |
# |    value_loss           | 4.74       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.61e+03    |
# |    ep_rew_mean          | 76.4        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 25          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.017895224 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.5       |
# |    explained_variance   | 0.0109      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0132     |
# |    reward               | 1.9743078   |
# |    std                  | 1.07        |
# |    value_loss           | 73.2        |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/ppo")

# %%
test_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}
    

env_test = StockTradingEnv(df = test, turbulence_threshold = 70, **test_kwargs)

# %%
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_ppo, 
    environment = env_test)
# Out:
# hit end!

# %%
# conbime the df account value and the df_actions
merged_df = df_account_value_ppo.merge(df_actions_ppo, on="date", how="inner")

merged_df.to_csv("results/result_ppo.csv")

# %%
merged_df
# Out:
#            date  account_value  sh600028  sh600029  sh600276  sh600309
# 0    2021-01-04   1.000000e+06         4         6        11         0  \
# 1    2021-01-05   1.005347e+06         4         6        11         0
# 2    2021-01-06   1.006488e+06        -8       -12       -22         0
# 3    2021-01-07   1.006222e+06         0         0         0         0
# 4    2021-01-08   1.006222e+06         4         6        11         0
# ..          ...            ...       ...       ...       ...       ...
# 538  2023-03-24   6.655110e+05        -9        32         0         0
# 539  2023-03-27   6.722534e+05       -12        35         0         0
# 540  2023-03-28   6.701566e+05        -5        35         0         0
# 541  2023-03-29   6.721989e+05         0        35         0         0
# 542  2023-03-30   6.772519e+05         0        35         0         0
#
#      sh600436  sh600519  sh600887  sh600900  ...  sh601939  sz000002
# 0          13         0         0         9  ...         0         0  \
# 1          13         0         0         9  ...         0         0
# 2         -26         0         0       -18  ...         0         0
# 3           0         0         0         0  ...         0         0
# 4          13         0         0         9  ...         0         0
# ..        ...       ...       ...       ...  ...       ...       ...
# 538         0         0         0         0  ...         0         7
# 539         0         0         0         0  ...         0         9
# 540         0         0         0         0  ...         0         9
# 541         0         0         0         0  ...         0         9
# 542         0         0         0         0  ...         0         9
#
#      sz000725  sz000858  sz000895  sz002230  sz002352  sz002594  sz002714
# 0           0         2        11         0         5        18        20  \
# 1           0         2        11         0         5        18        20
# 2           0        -4       -22         0       -10       -36       -40
# 3           0         0         0         0         0         0         0
# 4           0         2        11         0         5        18        20
# ..        ...       ...       ...       ...       ...       ...       ...
# 538        24         0        -5         0         0         2       -22
# 539        22         0        -5         0        -1         0       -25
# 540        22         0        -5         0        -1         0       -25
# 541         0         0        -5         0        -1         0       -25
# 542         0         0        -5         0        -1         0       -25
#
#      sz300015
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 538         1
# 539         0
# 540         0
# 541         0
# 542         0
#
# [543 rows x 32 columns]
